# %%
import numpy as np
import pandas as pd
import altair as alt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0d92f1f8-920d-4d9b-9372-5476e89923f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d92f1f8-920d-4d9b-9372-5476e89923f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving melb_data.csv to melb_data.csv

# %%
df = pd.read_csv("melb_data.csv", usecols = ['Price', 'Landsize', 'Distance', 'Type', 'Regionname'])

# %%
df = df[(df.Price < 3_000_000) & (df.Landsize < 1200)].sample(n=1000).reset_index(drop=True)

# %%
df.head()
# Out:
#   Type      Price  Distance  Landsize             Regionname
# 0    h  1540000.0       3.3     149.0  Southern Metropolitan
# 1    h  1310000.0       5.2     302.0  Northern Metropolitan
# 2    h  1115000.0       6.3     446.0   Western Metropolitan
# 3    h   697500.0      10.8     531.0   Western Metropolitan
# 4    h  1165000.0       2.6     167.0  Northern Metropolitan

# %%
df.tail()
# Out:
#     Type     Price  Distance  Landsize                  Regionname
# 995    h  950000.0       6.8     169.0        Western Metropolitan
# 996    h  981000.0      11.7     633.0        Western Metropolitan
# 997    h  922000.0      14.9     798.0       Northern Metropolitan
# 998    h  835000.0      14.5     447.0       Northern Metropolitan
# 999    h  820000.0      21.5     445.0  South-Eastern Metropolitan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Type        1000 non-null   object
#  1   Price       1000 non-null   float64
#  2   Distance    1000 non-null   float64
#  3   Landsize    1000 non-null   float64
#  4   Regionname  1000 non-null   object
# dtypes: float64(3), object(2)
# memory usage: 39.2+ KB

# %%
alt.Chart(df).mark_circle(size=50).encode(
    x='Price',
    y='Distance',
    color='Type'
).properties(
    height=350, width=500
)
# Out:
# alt.Chart(...)

# %%
selection = alt.selection_multi(fields=['Type'], bind='legend')

# %%
alt.Chart(df).mark_circle(size=50).encode(
   x='Price',
   y='Distance',
   color='Type',
   opacity=alt.condition(selection, alt.value(1), alt.value(0.1))
).properties(
   height=350, width=500
).add_selection(
   selection
)
# Out:
# alt.Chart(...)

# %%
selection = alt.selection_interval()

# %%
chart1 = alt.Chart(df).mark_circle(size=50).encode(
  x='Landsize',
  y='Distance',
  color='Type'
).properties(
  height=350, width=500
).add_selection(
  selection
)
chart2 = alt.Chart(df).mark_bar().encode(
  alt.X('Price:Q', bin=True), alt.Y('count()')
).transform_filter(
  selection
)

# %%
chart1 | chart2
# Out:
# alt.HConcatChart(...)

# %%
selection = alt.selection_interval()
chart1 = alt.Chart(df).mark_circle(size=50).encode(
   x='Landsize',
   y='Distance',
   color='Type'
).properties(
   height=350, width=500
).transform_filter(
   selection
)
chart2 = alt.Chart(df).mark_bar().encode(
   alt.X('Price:Q', bin=True), alt.Y('count()')
).add_selection(
   selection
)
chart1 | chart2
# Out:
# alt.HConcatChart(...)
